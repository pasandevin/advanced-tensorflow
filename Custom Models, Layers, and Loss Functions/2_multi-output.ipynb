# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 915us/sample - loss: 272.0792 - y1_output_loss: 129.4304 - y2_output_loss: 140.7345 - y1_output_root_mean_squared_error: 11.4169 - y2_output_root_mean_squared_error: 11.9052 - val_loss: 28.7542 - val_y1_output_loss: 14.4565 - val_y2_output_loss: 13.6011 - val_y1_output_root_mean_squared_error: 3.8577 - val_y2_output_root_mean_squared_error: 3.7245
# Epoch 2/500
# 614/614 [==============================] - 0s 142us/sample - loss: 33.8236 - y1_output_loss: 13.3458 - y2_output_loss: 20.6246 - y1_output_root_mean_squared_error: 3.6372 - y2_output_root_mean_squared_error: 4.5381 - val_loss: 20.3973 - val_y1_output_loss: 8.1341 - val_y2_output_loss: 11.8206 - val_y1_output_root_mean_squared_error: 2.8911 - val_y2_output_root_mean_squared_error: 3.4697
# Epoch 3/500
# 614/614 [==============================] - 0s 134us/sample - loss: 31.7048 - y1_output_loss: 11.7159 - y2_output_loss: 19.9759 - y1_output_root_mean_squared_error: 3.4242 - y2_output_root_mean_squared_error: 4.4698 - val_loss: 27.3675 - val_y1_output_loss: 9.2801 - val_y2_output_loss: 17.4104 - val_y1_output_root_mean_squared_error: 3.0878 - val_y2_output_root_mean_squared_error: 4.2229
# Epoch 4/500
# 614/614 [==============================] - 0s 134us/sample - loss: 25.1480 - y1_output_loss: 9.8921 - y2_output_loss: 16.4257 - y1_output_root_mean_squared_error: 3.1260 - y2_output_root_mean_squared_error: 3.9212 - val_loss: 115.7202 - val_y1_output_loss: 29.9892 - val_y2_output_loss: 81.9424 - val_y1_output_root_mean_squared_error: 5.5713 - val_y2_output_root_mean_squared_error: 9.2022
# Epoch 5/500
# 614/614 [==============================] - 0s 134us/sample - loss: 29.3634 - y1_output_loss: 10.3025 - y2_output_loss: 18.8682 - y1_output_root_mean_squared_error: 3.2148 - y2_output_root_mean_squared_error: 4.3622 - val_loss: 15.8285 - val_y1_output_loss: 7.2144 - val_y2_output_loss: 8.4076 - val_y1_output_root_mean_squared_error: 2.7152 - val_y2_output_root_mean_squared_error: 2.9080
# Epoch 6/500
# 614/614 [==============================] - 0s 133us/sample - loss: 23.5984 - y1_output_loss: 9.1829 - y2_output_loss: 14.4174 - y1_output_root_mean_squared_error: 3.0213 - y2_output_root_mean_squared_error: 3.8039 - val_loss: 18.3933 - val_y1_output_loss: 7.8714 - val_y2_output_loss: 10.0977 - val_y1_output_root_mean_squared_error: 2.8430 - val_y2_output_root_mean_squared_error: 3.2110
# Epoch 7/500
# 614/614 [==============================] - 0s 135us/sample - loss: 25.1824 - y1_output_loss: 9.3452 - y2_output_loss: 16.6515 - y1_output_root_mean_squared_error: 3.0159 - y2_output_root_mean_squared_error: 4.0109 - val_loss: 95.2014 - val_y1_output_loss: 16.6954 - val_y2_output_loss: 75.6195 - val_y1_output_root_mean_squared_error: 4.1552 - val_y2_output_root_mean_squared_error: 8.8281
# Epoch 8/500
# 614/614 [==============================] - 0s 132us/sample - loss: 21.4784 - y1_output_loss: 8.4099 - y2_output_loss: 13.0252 - y1_output_root_mean_squared_error: 2.8970 - y2_output_root_mean_squared_error: 3.6174 - val_loss: 27.1123 - val_y1_output_loss: 9.7326 - val_y2_output_loss: 16.8083 - val_y1_output_root_mean_squared_error: 3.1649 - val_y2_output_root_mean_squared_error: 4.1347
# Epoch 9/500
# 614/614 [==============================] - 0s 133us/sample - loss: 19.2109 - y1_output_loss: 7.4204 - y2_output_loss: 11.7281 - y1_output_root_mean_squared_error: 2.7302 - y2_output_root_mean_squared_error: 3.4288 - val_loss: 25.8603 - val_y1_output_loss: 8.7253 - val_y2_output_loss: 16.4658 - val_y1_output_root_mean_squared_error: 2.9950 - val_y2_output_root_mean_squared_error: 4.1098
# Epoch 10/500
# 614/614 [==============================] - 0s 139us/sample - loss: 20.7039 - y1_output_loss: 8.0265 - y2_output_loss: 12.5480 - y1_output_root_mean_squared_error: 2.8381 - y2_output_root_mean_squared_error: 3.5565 - val_loss: 17.3354 - val_y1_output_loss: 8.4008 - val_y2_output_loss: 8.4699 - val_y1_output_root_mean_squared_error: 2.9462 - val_y2_output_root_mean_squared_error: 2.9420
# Epoch 11/500
# 614/614 [==============================] - 0s 138us/sample - loss: 20.9514 - y1_output_loss: 7.5890 - y2_output_loss: 13.2186 - y1_output_root_mean_squared_error: 2.7636 - y2_output_root_mean_squared_error: 3.6488 - val_loss: 13.6899 - val_y1_output_loss: 5.7571 - val_y2_output_loss: 7.5470 - val_y1_output_root_mean_squared_error: 2.4362 - val_y2_output_root_mean_squared_error: 2.7847
# Epoch 12/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.9815 - y1_output_loss: 7.3991 - y2_output_loss: 13.5769 - y1_output_root_mean_squared_error: 2.7143 - y2_output_root_mean_squared_error: 3.6897 - val_loss: 18.6028 - val_y1_output_loss: 7.0580 - val_y2_output_loss: 10.9876 - val_y1_output_root_mean_squared_error: 2.7013 - val_y2_output_root_mean_squared_error: 3.3624
# Epoch 13/500
# 614/614 [==============================] - 0s 128us/sample - loss: 19.5215 - y1_output_loss: 7.0297 - y2_output_loss: 12.5488 - y1_output_root_mean_squared_error: 2.6530 - y2_output_root_mean_squared_error: 3.5331 - val_loss: 20.0935 - val_y1_output_loss: 6.5633 - val_y2_output_loss: 13.0245 - val_y1_output_root_mean_squared_error: 2.5946 - val_y2_output_root_mean_squared_error: 3.6553
# Epoch 14/500
# 614/614 [==============================] - 0s 130us/sample - loss: 16.2145 - y1_output_loss: 6.2272 - y2_output_loss: 9.9493 - y1_output_root_mean_squared_error: 2.4888 - y2_output_root_mean_squared_error: 3.1655 - val_loss: 17.7237 - val_y1_output_loss: 6.7793 - val_y2_output_loss: 10.3831 - val_y1_output_root_mean_squared_error: 2.6468 - val_y2_output_root_mean_squared_error: 3.2739
# Epoch 15/500
# 614/614 [==============================] - 0s 130us/sample - loss: 21.8011 - y1_output_loss: 7.5165 - y2_output_loss: 14.3412 - y1_output_root_mean_squared_error: 2.7317 - y2_output_root_mean_squared_error: 3.7867 - val_loss: 26.0616 - val_y1_output_loss: 7.4941 - val_y2_output_loss: 17.7427 - val_y1_output_root_mean_squared_error: 2.7852 - val_y2_output_root_mean_squared_error: 4.2783
# Epoch 16/500
# 614/614 [==============================] - 0s 130us/sample - loss: 16.2109 - y1_output_loss: 5.9473 - y2_output_loss: 10.3135 - y1_output_root_mean_squared_error: 2.4291 - y2_output_root_mean_squared_error: 3.2109 - val_loss: 36.0895 - val_y1_output_loss: 10.1911 - val_y2_output_loss: 24.8558 - val_y1_output_root_mean_squared_error: 3.2405 - val_y2_output_root_mean_squared_error: 5.0585
# Epoch 17/500
# 614/614 [==============================] - 0s 129us/sample - loss: 17.8380 - y1_output_loss: 6.2230 - y2_output_loss: 11.4722 - y1_output_root_mean_squared_error: 2.5052 - y2_output_root_mean_squared_error: 3.4003 - val_loss: 12.0487 - val_y1_output_loss: 4.6587 - val_y2_output_loss: 7.0159 - val_y1_output_root_mean_squared_error: 2.1955 - val_y2_output_root_mean_squared_error: 2.6886
# Epoch 18/500
# 614/614 [==============================] - 0s 129us/sample - loss: 13.8112 - y1_output_loss: 5.2802 - y2_output_loss: 8.4087 - y1_output_root_mean_squared_error: 2.3073 - y2_output_root_mean_squared_error: 2.9133 - val_loss: 10.0587 - val_y1_output_loss: 4.3037 - val_y2_output_loss: 5.4537 - val_y1_output_root_mean_squared_error: 2.1063 - val_y2_output_root_mean_squared_error: 2.3711
# Epoch 19/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.5573 - y1_output_loss: 4.9322 - y2_output_loss: 8.5465 - y1_output_root_mean_squared_error: 2.2283 - y2_output_root_mean_squared_error: 2.9312 - val_loss: 15.1304 - val_y1_output_loss: 5.4782 - val_y2_output_loss: 9.1489 - val_y1_output_root_mean_squared_error: 2.3789 - val_y2_output_root_mean_squared_error: 3.0775
# Epoch 20/500
# 614/614 [==============================] - 0s 128us/sample - loss: 15.4316 - y1_output_loss: 5.2872 - y2_output_loss: 10.0565 - y1_output_root_mean_squared_error: 2.3093 - y2_output_root_mean_squared_error: 3.1779 - val_loss: 12.7108 - val_y1_output_loss: 4.8267 - val_y2_output_loss: 7.4738 - val_y1_output_root_mean_squared_error: 2.2301 - val_y2_output_root_mean_squared_error: 2.7817
# Epoch 21/500
# 614/614 [==============================] - 0s 128us/sample - loss: 15.6204 - y1_output_loss: 5.4291 - y2_output_loss: 10.0643 - y1_output_root_mean_squared_error: 2.3387 - y2_output_root_mean_squared_error: 3.1861 - val_loss: 9.2787 - val_y1_output_loss: 4.0405 - val_y2_output_loss: 4.9367 - val_y1_output_root_mean_squared_error: 2.0435 - val_y2_output_root_mean_squared_error: 2.2590
# Epoch 22/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.5585 - y1_output_loss: 5.0642 - y2_output_loss: 9.7688 - y1_output_root_mean_squared_error: 2.2392 - y2_output_root_mean_squared_error: 3.0894 - val_loss: 25.9974 - val_y1_output_loss: 6.4193 - val_y2_output_loss: 18.7078 - val_y1_output_root_mean_squared_error: 2.5771 - val_y2_output_root_mean_squared_error: 4.3995
# Epoch 23/500
# 614/614 [==============================] - 0s 131us/sample - loss: 16.0434 - y1_output_loss: 5.3184 - y2_output_loss: 10.6109 - y1_output_root_mean_squared_error: 2.3104 - y2_output_root_mean_squared_error: 3.2720 - val_loss: 9.6234 - val_y1_output_loss: 4.3763 - val_y2_output_loss: 4.9637 - val_y1_output_root_mean_squared_error: 2.1277 - val_y2_output_root_mean_squared_error: 2.2575
# Epoch 24/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.8649 - y1_output_loss: 4.0597 - y2_output_loss: 6.7297 - y1_output_root_mean_squared_error: 2.0225 - y2_output_root_mean_squared_error: 2.6028 - val_loss: 14.2716 - val_y1_output_loss: 4.8725 - val_y2_output_loss: 8.9372 - val_y1_output_root_mean_squared_error: 2.2466 - val_y2_output_root_mean_squared_error: 3.0371
# Epoch 25/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.3705 - y1_output_loss: 3.9576 - y2_output_loss: 7.4869 - y1_output_root_mean_squared_error: 1.9810 - y2_output_root_mean_squared_error: 2.7288 - val_loss: 24.2385 - val_y1_output_loss: 5.8833 - val_y2_output_loss: 17.5723 - val_y1_output_root_mean_squared_error: 2.4680 - val_y2_output_root_mean_squared_error: 4.2600
# Epoch 26/500
# 614/614 [==============================] - 0s 135us/sample - loss: 18.1589 - y1_output_loss: 5.3596 - y2_output_loss: 12.6582 - y1_output_root_mean_squared_error: 2.3216 - y2_output_root_mean_squared_error: 3.5734 - val_loss: 18.3148 - val_y1_output_loss: 6.0468 - val_y2_output_loss: 11.6694 - val_y1_output_root_mean_squared_error: 2.5020 - val_y2_output_root_mean_squared_error: 3.4720
# Epoch 27/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.5876 - y1_output_loss: 3.7114 - y2_output_loss: 6.7942 - y1_output_root_mean_squared_error: 1.9343 - y2_output_root_mean_squared_error: 2.6165 - val_loss: 11.2529 - val_y1_output_loss: 4.7519 - val_y2_output_loss: 6.1537 - val_y1_output_root_mean_squared_error: 2.2149 - val_y2_output_root_mean_squared_error: 2.5194
# Epoch 28/500
# 614/614 [==============================] - 0s 130us/sample - loss: 11.2247 - y1_output_loss: 3.6942 - y2_output_loss: 7.5883 - y1_output_root_mean_squared_error: 1.9167 - y2_output_root_mean_squared_error: 2.7479 - val_loss: 13.4077 - val_y1_output_loss: 4.7025 - val_y2_output_loss: 8.2484 - val_y1_output_root_mean_squared_error: 2.2090 - val_y2_output_root_mean_squared_error: 2.9203
# Epoch 29/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.8946 - y1_output_loss: 3.5318 - y2_output_loss: 6.5181 - y1_output_root_mean_squared_error: 1.8780 - y2_output_root_mean_squared_error: 2.5234 - val_loss: 32.0481 - val_y1_output_loss: 6.2764 - val_y2_output_loss: 24.7674 - val_y1_output_root_mean_squared_error: 2.5524 - val_y2_output_root_mean_squared_error: 5.0531
# Epoch 30/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.6589 - y1_output_loss: 4.7711 - y2_output_loss: 9.9356 - y1_output_root_mean_squared_error: 2.1651 - y2_output_root_mean_squared_error: 3.1577 - val_loss: 18.4264 - val_y1_output_loss: 6.4143 - val_y2_output_loss: 11.3866 - val_y1_output_root_mean_squared_error: 2.5759 - val_y2_output_root_mean_squared_error: 3.4338
# Epoch 31/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.1774 - y1_output_loss: 4.1786 - y2_output_loss: 8.8781 - y1_output_root_mean_squared_error: 2.0536 - y2_output_root_mean_squared_error: 2.9934 - val_loss: 21.3035 - val_y1_output_loss: 9.3308 - val_y2_output_loss: 11.2606 - val_y1_output_root_mean_squared_error: 3.1048 - val_y2_output_root_mean_squared_error: 3.4152
# Epoch 32/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.2051 - y1_output_loss: 3.4325 - y2_output_loss: 6.7179 - y1_output_root_mean_squared_error: 1.8611 - y2_output_root_mean_squared_error: 2.5964 - val_loss: 35.8065 - val_y1_output_loss: 7.3261 - val_y2_output_loss: 27.2407 - val_y1_output_root_mean_squared_error: 2.7563 - val_y2_output_root_mean_squared_error: 5.3113
# Epoch 33/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.0978 - y1_output_loss: 2.9290 - y2_output_loss: 6.1046 - y1_output_root_mean_squared_error: 1.7163 - y2_output_root_mean_squared_error: 2.4804 - val_loss: 9.2268 - val_y1_output_loss: 3.2292 - val_y2_output_loss: 5.7176 - val_y1_output_root_mean_squared_error: 1.8241 - val_y2_output_root_mean_squared_error: 2.4289
# Epoch 34/500
# 614/614 [==============================] - 0s 129us/sample - loss: 12.5102 - y1_output_loss: 3.9081 - y2_output_loss: 8.4908 - y1_output_root_mean_squared_error: 1.9855 - y2_output_root_mean_squared_error: 2.9271 - val_loss: 10.7220 - val_y1_output_loss: 3.5118 - val_y2_output_loss: 6.8641 - val_y1_output_root_mean_squared_error: 1.9054 - val_y2_output_root_mean_squared_error: 2.6630
# Epoch 35/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.6671 - y1_output_loss: 3.0674 - y2_output_loss: 6.5252 - y1_output_root_mean_squared_error: 1.7558 - y2_output_root_mean_squared_error: 2.5660 - val_loss: 7.4084 - val_y1_output_loss: 2.8888 - val_y2_output_loss: 4.2808 - val_y1_output_root_mean_squared_error: 1.7270 - val_y2_output_root_mean_squared_error: 2.1038
# Epoch 36/500
# 614/614 [==============================] - 0s 133us/sample - loss: 10.0036 - y1_output_loss: 2.9610 - y2_output_loss: 6.9546 - y1_output_root_mean_squared_error: 1.7280 - y2_output_root_mean_squared_error: 2.6491 - val_loss: 7.3124 - val_y1_output_loss: 2.8779 - val_y2_output_loss: 4.1999 - val_y1_output_root_mean_squared_error: 1.7206 - val_y2_output_root_mean_squared_error: 2.0861
# Epoch 37/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.7959 - y1_output_loss: 2.6066 - y2_output_loss: 5.2424 - y1_output_root_mean_squared_error: 1.6150 - y2_output_root_mean_squared_error: 2.2776 - val_loss: 7.4606 - val_y1_output_loss: 2.6070 - val_y2_output_loss: 4.6030 - val_y1_output_root_mean_squared_error: 1.6439 - val_y2_output_root_mean_squared_error: 2.1813
# Epoch 38/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.5768 - y1_output_loss: 2.8026 - y2_output_loss: 5.8228 - y1_output_root_mean_squared_error: 1.6627 - y2_output_root_mean_squared_error: 2.4109 - val_loss: 8.0038 - val_y1_output_loss: 3.1672 - val_y2_output_loss: 4.5565 - val_y1_output_root_mean_squared_error: 1.8099 - val_y2_output_root_mean_squared_error: 2.1744
# Epoch 39/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.2716 - y1_output_loss: 2.7559 - y2_output_loss: 6.6832 - y1_output_root_mean_squared_error: 1.6358 - y2_output_root_mean_squared_error: 2.5682 - val_loss: 7.5830 - val_y1_output_loss: 2.5916 - val_y2_output_loss: 4.7658 - val_y1_output_root_mean_squared_error: 1.6328 - val_y2_output_root_mean_squared_error: 2.2174
# Epoch 40/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.9418 - y1_output_loss: 2.5970 - y2_output_loss: 6.3065 - y1_output_root_mean_squared_error: 1.6169 - y2_output_root_mean_squared_error: 2.5154 - val_loss: 16.1679 - val_y1_output_loss: 4.2450 - val_y2_output_loss: 11.3678 - val_y1_output_root_mean_squared_error: 2.0906 - val_y2_output_root_mean_squared_error: 3.4347
# Epoch 41/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.0960 - y1_output_loss: 2.6180 - y2_output_loss: 5.4799 - y1_output_root_mean_squared_error: 1.6204 - y2_output_root_mean_squared_error: 2.3388 - val_loss: 7.7407 - val_y1_output_loss: 2.6238 - val_y2_output_loss: 4.8432 - val_y1_output_root_mean_squared_error: 1.6486 - val_y2_output_root_mean_squared_error: 2.2412
# Epoch 42/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.5440 - y1_output_loss: 2.5974 - y2_output_loss: 5.9236 - y1_output_root_mean_squared_error: 1.6045 - y2_output_root_mean_squared_error: 2.4433 - val_loss: 7.0576 - val_y1_output_loss: 2.8457 - val_y2_output_loss: 4.0074 - val_y1_output_root_mean_squared_error: 1.7039 - val_y2_output_root_mean_squared_error: 2.0382
# Epoch 43/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.7173 - y1_output_loss: 2.5640 - y2_output_loss: 6.0912 - y1_output_root_mean_squared_error: 1.6031 - y2_output_root_mean_squared_error: 2.4794 - val_loss: 8.9429 - val_y1_output_loss: 2.9874 - val_y2_output_loss: 5.6823 - val_y1_output_root_mean_squared_error: 1.7573 - val_y2_output_root_mean_squared_error: 2.4197
# Epoch 44/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.1931 - y1_output_loss: 2.0450 - y2_output_loss: 4.1743 - y1_output_root_mean_squared_error: 1.4318 - y2_output_root_mean_squared_error: 2.0354 - val_loss: 8.1224 - val_y1_output_loss: 2.9578 - val_y2_output_loss: 4.8843 - val_y1_output_root_mean_squared_error: 1.7489 - val_y2_output_root_mean_squared_error: 2.2503
# Epoch 45/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.3320 - y1_output_loss: 2.0000 - y2_output_loss: 4.3097 - y1_output_root_mean_squared_error: 1.4169 - y2_output_root_mean_squared_error: 2.0795 - val_loss: 9.5051 - val_y1_output_loss: 2.8524 - val_y2_output_loss: 6.3164 - val_y1_output_root_mean_squared_error: 1.7201 - val_y2_output_root_mean_squared_error: 2.5586
# Epoch 46/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.6230 - y1_output_loss: 2.0847 - y2_output_loss: 4.5446 - y1_output_root_mean_squared_error: 1.4358 - y2_output_root_mean_squared_error: 2.1358 - val_loss: 6.5225 - val_y1_output_loss: 2.3045 - val_y2_output_loss: 4.0210 - val_y1_output_root_mean_squared_error: 1.5418 - val_y2_output_root_mean_squared_error: 2.0360
# Epoch 47/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.3299 - y1_output_loss: 2.1237 - y2_output_loss: 5.1562 - y1_output_root_mean_squared_error: 1.4580 - y2_output_root_mean_squared_error: 2.2813 - val_loss: 5.3092 - val_y1_output_loss: 1.9613 - val_y2_output_loss: 3.1695 - val_y1_output_root_mean_squared_error: 1.4269 - val_y2_output_root_mean_squared_error: 1.8092
# Epoch 48/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.4541 - y1_output_loss: 2.0681 - y2_output_loss: 5.3245 - y1_output_root_mean_squared_error: 1.4417 - y2_output_root_mean_squared_error: 2.3185 - val_loss: 6.8204 - val_y1_output_loss: 2.5344 - val_y2_output_loss: 4.0435 - val_y1_output_root_mean_squared_error: 1.6213 - val_y2_output_root_mean_squared_error: 2.0474
# Epoch 49/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.8673 - y1_output_loss: 2.0359 - y2_output_loss: 4.8691 - y1_output_root_mean_squared_error: 1.4304 - y2_output_root_mean_squared_error: 2.1957 - val_loss: 8.6731 - val_y1_output_loss: 2.5993 - val_y2_output_loss: 5.7908 - val_y1_output_root_mean_squared_error: 1.6412 - val_y2_output_root_mean_squared_error: 2.4453
# Epoch 50/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.9201 - y1_output_loss: 2.1291 - y2_output_loss: 4.7658 - y1_output_root_mean_squared_error: 1.4636 - y2_output_root_mean_squared_error: 2.1859 - val_loss: 10.4076 - val_y1_output_loss: 3.8026 - val_y2_output_loss: 6.3291 - val_y1_output_root_mean_squared_error: 1.9714 - val_y2_output_root_mean_squared_error: 2.5537
# Epoch 51/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.6125 - y1_output_loss: 2.1216 - y2_output_loss: 5.4982 - y1_output_root_mean_squared_error: 1.4630 - y2_output_root_mean_squared_error: 2.3393 - val_loss: 11.7376 - val_y1_output_loss: 3.2354 - val_y2_output_loss: 8.1839 - val_y1_output_root_mean_squared_error: 1.8212 - val_y2_output_root_mean_squared_error: 2.9018
# Epoch 52/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.2582 - y1_output_loss: 2.0580 - y2_output_loss: 5.1366 - y1_output_root_mean_squared_error: 1.4412 - y2_output_root_mean_squared_error: 2.2762 - val_loss: 6.8478 - val_y1_output_loss: 2.3261 - val_y2_output_loss: 4.2928 - val_y1_output_root_mean_squared_error: 1.5520 - val_y2_output_root_mean_squared_error: 2.1069
# Epoch 53/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.6132 - y1_output_loss: 1.7078 - y2_output_loss: 3.8818 - y1_output_root_mean_squared_error: 1.3105 - y2_output_root_mean_squared_error: 1.9738 - val_loss: 13.6520 - val_y1_output_loss: 4.1569 - val_y2_output_loss: 9.1399 - val_y1_output_root_mean_squared_error: 2.0502 - val_y2_output_root_mean_squared_error: 3.0739
# Epoch 54/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.7143 - y1_output_loss: 1.6764 - y2_output_loss: 4.2183 - y1_output_root_mean_squared_error: 1.2800 - y2_output_root_mean_squared_error: 2.0189 - val_loss: 22.3767 - val_y1_output_loss: 10.2672 - val_y2_output_loss: 11.3252 - val_y1_output_root_mean_squared_error: 3.2642 - val_y2_output_root_mean_squared_error: 3.4237
# Epoch 55/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.4408 - y1_output_loss: 2.1196 - y2_output_loss: 4.3409 - y1_output_root_mean_squared_error: 1.4567 - y2_output_root_mean_squared_error: 2.0782 - val_loss: 14.0090 - val_y1_output_loss: 3.8236 - val_y2_output_loss: 9.6940 - val_y1_output_root_mean_squared_error: 1.9903 - val_y2_output_root_mean_squared_error: 3.1698
# Epoch 56/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.6061 - y1_output_loss: 1.5861 - y2_output_loss: 4.0132 - y1_output_root_mean_squared_error: 1.2605 - y2_output_root_mean_squared_error: 2.0043 - val_loss: 7.9846 - val_y1_output_loss: 2.8827 - val_y2_output_loss: 4.9036 - val_y1_output_root_mean_squared_error: 1.7257 - val_y2_output_root_mean_squared_error: 2.2375
# Epoch 57/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.9406 - y1_output_loss: 1.6596 - y2_output_loss: 4.2463 - y1_output_root_mean_squared_error: 1.2884 - y2_output_root_mean_squared_error: 2.0690 - val_loss: 5.2294 - val_y1_output_loss: 1.6344 - val_y2_output_loss: 3.4490 - val_y1_output_root_mean_squared_error: 1.2962 - val_y2_output_root_mean_squared_error: 1.8840
# Epoch 58/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.0072 - y1_output_loss: 1.6874 - y2_output_loss: 4.3156 - y1_output_root_mean_squared_error: 1.3040 - y2_output_root_mean_squared_error: 2.0753 - val_loss: 9.2617 - val_y1_output_loss: 2.3969 - val_y2_output_loss: 6.6014 - val_y1_output_root_mean_squared_error: 1.5566 - val_y2_output_root_mean_squared_error: 2.6151
# Epoch 59/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.4623 - y1_output_loss: 1.8169 - y2_output_loss: 4.6441 - y1_output_root_mean_squared_error: 1.3529 - y2_output_root_mean_squared_error: 2.1522 - val_loss: 6.0827 - val_y1_output_loss: 1.5172 - val_y2_output_loss: 4.3535 - val_y1_output_root_mean_squared_error: 1.2537 - val_y2_output_root_mean_squared_error: 2.1239
# Epoch 60/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.0509 - y1_output_loss: 1.8278 - y2_output_loss: 4.2819 - y1_output_root_mean_squared_error: 1.3559 - y2_output_root_mean_squared_error: 2.0525 - val_loss: 21.6180 - val_y1_output_loss: 4.5900 - val_y2_output_loss: 16.2804 - val_y1_output_root_mean_squared_error: 2.1815 - val_y2_output_root_mean_squared_error: 4.1060
# Epoch 61/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.6739 - y1_output_loss: 1.5957 - y2_output_loss: 4.2065 - y1_output_root_mean_squared_error: 1.2679 - y2_output_root_mean_squared_error: 2.0165 - val_loss: 25.0722 - val_y1_output_loss: 4.1798 - val_y2_output_loss: 20.2748 - val_y1_output_root_mean_squared_error: 2.0697 - val_y2_output_root_mean_squared_error: 4.5594
# Epoch 62/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.9497 - y1_output_loss: 1.5013 - y2_output_loss: 4.4789 - y1_output_root_mean_squared_error: 1.2238 - y2_output_root_mean_squared_error: 2.1100 - val_loss: 8.8942 - val_y1_output_loss: 4.2806 - val_y2_output_loss: 4.2983 - val_y1_output_root_mean_squared_error: 2.1081 - val_y2_output_root_mean_squared_error: 2.1096
# Epoch 63/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.1650 - y1_output_loss: 1.3120 - y2_output_loss: 3.8088 - y1_output_root_mean_squared_error: 1.1498 - y2_output_root_mean_squared_error: 1.9603 - val_loss: 4.6020 - val_y1_output_loss: 1.5994 - val_y2_output_loss: 2.8364 - val_y1_output_root_mean_squared_error: 1.2874 - val_y2_output_root_mean_squared_error: 1.7159
# Epoch 64/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.9874 - y1_output_loss: 1.7532 - y2_output_loss: 4.3914 - y1_output_root_mean_squared_error: 1.2971 - y2_output_root_mean_squared_error: 2.0749 - val_loss: 20.5498 - val_y1_output_loss: 8.0915 - val_y2_output_loss: 12.0799 - val_y1_output_root_mean_squared_error: 2.8791 - val_y2_output_root_mean_squared_error: 3.5015
# Epoch 65/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.8975 - y1_output_loss: 1.5568 - y2_output_loss: 4.3313 - y1_output_root_mean_squared_error: 1.2497 - y2_output_root_mean_squared_error: 2.0822 - val_loss: 5.5918 - val_y1_output_loss: 1.7624 - val_y2_output_loss: 3.6467 - val_y1_output_root_mean_squared_error: 1.3465 - val_y2_output_root_mean_squared_error: 1.9439
# Epoch 66/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.3725 - y1_output_loss: 1.5795 - y2_output_loss: 4.7882 - y1_output_root_mean_squared_error: 1.2581 - y2_output_root_mean_squared_error: 2.1885 - val_loss: 15.0446 - val_y1_output_loss: 3.1285 - val_y2_output_loss: 11.6865 - val_y1_output_root_mean_squared_error: 1.7733 - val_y2_output_root_mean_squared_error: 3.4496
# Epoch 67/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.8473 - y1_output_loss: 1.4636 - y2_output_loss: 4.3300 - y1_output_root_mean_squared_error: 1.2147 - y2_output_root_mean_squared_error: 2.0909 - val_loss: 4.1731 - val_y1_output_loss: 1.3762 - val_y2_output_loss: 2.6653 - val_y1_output_root_mean_squared_error: 1.1912 - val_y2_output_root_mean_squared_error: 1.6596
# Epoch 68/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.2190 - y1_output_loss: 1.4325 - y2_output_loss: 3.7794 - y1_output_root_mean_squared_error: 1.1968 - y2_output_root_mean_squared_error: 1.9459 - val_loss: 4.1627 - val_y1_output_loss: 1.5438 - val_y2_output_loss: 2.5349 - val_y1_output_root_mean_squared_error: 1.2582 - val_y2_output_root_mean_squared_error: 1.6061
# Epoch 69/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.0117 - y1_output_loss: 0.9851 - y2_output_loss: 2.9958 - y1_output_root_mean_squared_error: 0.9961 - y2_output_root_mean_squared_error: 1.7377 - val_loss: 3.8456 - val_y1_output_loss: 0.9897 - val_y2_output_loss: 2.7339 - val_y1_output_root_mean_squared_error: 1.0079 - val_y2_output_root_mean_squared_error: 1.6822
# Epoch 70/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.7076 - y1_output_loss: 1.1541 - y2_output_loss: 3.5145 - y1_output_root_mean_squared_error: 1.0788 - y2_output_root_mean_squared_error: 1.8825 - val_loss: 3.0926 - val_y1_output_loss: 0.8959 - val_y2_output_loss: 2.0887 - val_y1_output_root_mean_squared_error: 0.9611 - val_y2_output_root_mean_squared_error: 1.4727
# Epoch 71/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.4166 - y1_output_loss: 1.2942 - y2_output_loss: 4.1825 - y1_output_root_mean_squared_error: 1.1382 - y2_output_root_mean_squared_error: 2.0301 - val_loss: 4.7404 - val_y1_output_loss: 1.2868 - val_y2_output_loss: 3.3038 - val_y1_output_root_mean_squared_error: 1.1506 - val_y2_output_root_mean_squared_error: 1.8484
# Epoch 72/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.0667 - y1_output_loss: 0.9258 - y2_output_loss: 3.1106 - y1_output_root_mean_squared_error: 0.9659 - y2_output_root_mean_squared_error: 1.7702 - val_loss: 4.4227 - val_y1_output_loss: 1.3869 - val_y2_output_loss: 2.8762 - val_y1_output_root_mean_squared_error: 1.1986 - val_y2_output_root_mean_squared_error: 1.7281
# Epoch 73/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.6319 - y1_output_loss: 0.7885 - y2_output_loss: 2.8153 - y1_output_root_mean_squared_error: 0.8886 - y2_output_root_mean_squared_error: 1.6859 - val_loss: 3.2438 - val_y1_output_loss: 1.1909 - val_y2_output_loss: 1.9776 - val_y1_output_root_mean_squared_error: 1.0963 - val_y2_output_root_mean_squared_error: 1.4289
# Epoch 74/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.8169 - y1_output_loss: 1.1475 - y2_output_loss: 3.6675 - y1_output_root_mean_squared_error: 1.0742 - y2_output_root_mean_squared_error: 1.9139 - val_loss: 7.3343 - val_y1_output_loss: 2.4386 - val_y2_output_loss: 4.7051 - val_y1_output_root_mean_squared_error: 1.5865 - val_y2_output_root_mean_squared_error: 2.1949
# Epoch 75/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.8229 - y1_output_loss: 1.0376 - y2_output_loss: 2.7588 - y1_output_root_mean_squared_error: 1.0218 - y2_output_root_mean_squared_error: 1.6670 - val_loss: 4.1953 - val_y1_output_loss: 1.4876 - val_y2_output_loss: 2.6123 - val_y1_output_root_mean_squared_error: 1.2261 - val_y2_output_root_mean_squared_error: 1.6407
# Epoch 76/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.6949 - y1_output_loss: 0.8408 - y2_output_loss: 2.8354 - y1_output_root_mean_squared_error: 0.9180 - y2_output_root_mean_squared_error: 1.6888 - val_loss: 3.6108 - val_y1_output_loss: 1.1311 - val_y2_output_loss: 2.3701 - val_y1_output_root_mean_squared_error: 1.0746 - val_y2_output_root_mean_squared_error: 1.5672
# Epoch 77/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.5255 - y1_output_loss: 0.8120 - y2_output_loss: 2.7184 - y1_output_root_mean_squared_error: 0.8991 - y2_output_root_mean_squared_error: 1.6484 - val_loss: 2.8069 - val_y1_output_loss: 0.9084 - val_y2_output_loss: 1.8117 - val_y1_output_root_mean_squared_error: 0.9682 - val_y2_output_root_mean_squared_error: 1.3673
# Epoch 78/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.4886 - y1_output_loss: 0.7930 - y2_output_loss: 2.6933 - y1_output_root_mean_squared_error: 0.8928 - y2_output_root_mean_squared_error: 1.6406 - val_loss: 4.9741 - val_y1_output_loss: 1.0578 - val_y2_output_loss: 3.7654 - val_y1_output_root_mean_squared_error: 1.0410 - val_y2_output_root_mean_squared_error: 1.9724
# Epoch 79/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8633 - y1_output_loss: 0.9281 - y2_output_loss: 2.9025 - y1_output_root_mean_squared_error: 0.9664 - y2_output_root_mean_squared_error: 1.7116 - val_loss: 3.3133 - val_y1_output_loss: 1.2080 - val_y2_output_loss: 1.9940 - val_y1_output_root_mean_squared_error: 1.1159 - val_y2_output_root_mean_squared_error: 1.4381
# Epoch 80/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.8975 - y1_output_loss: 0.7582 - y2_output_loss: 2.2647 - y1_output_root_mean_squared_error: 0.8483 - y2_output_root_mean_squared_error: 1.4758 - val_loss: 113.4805 - val_y1_output_loss: 40.5208 - val_y2_output_loss: 69.3667 - val_y1_output_root_mean_squared_error: 6.4729 - val_y2_output_root_mean_squared_error: 8.4606
# Epoch 81/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.8486 - y1_output_loss: 1.2536 - y2_output_loss: 3.6096 - y1_output_root_mean_squared_error: 1.1219 - y2_output_root_mean_squared_error: 1.8947 - val_loss: 2.6873 - val_y1_output_loss: 0.8776 - val_y2_output_loss: 1.7211 - val_y1_output_root_mean_squared_error: 0.9502 - val_y2_output_root_mean_squared_error: 1.3358
# Epoch 82/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.5701 - y1_output_loss: 0.8783 - y2_output_loss: 2.6927 - y1_output_root_mean_squared_error: 0.9354 - y2_output_root_mean_squared_error: 1.6417 - val_loss: 5.3792 - val_y1_output_loss: 2.3571 - val_y2_output_loss: 2.9017 - val_y1_output_root_mean_squared_error: 1.5488 - val_y2_output_root_mean_squared_error: 1.7264
# Epoch 83/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4809 - y1_output_loss: 0.7675 - y2_output_loss: 2.6986 - y1_output_root_mean_squared_error: 0.8776 - y2_output_root_mean_squared_error: 1.6464 - val_loss: 6.6589 - val_y1_output_loss: 1.5614 - val_y2_output_loss: 4.8987 - val_y1_output_root_mean_squared_error: 1.2645 - val_y2_output_root_mean_squared_error: 2.2494
# Epoch 84/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.7456 - y1_output_loss: 0.9119 - y2_output_loss: 2.8118 - y1_output_root_mean_squared_error: 0.9585 - y2_output_root_mean_squared_error: 1.6813 - val_loss: 4.8447 - val_y1_output_loss: 1.4448 - val_y2_output_loss: 3.2563 - val_y1_output_root_mean_squared_error: 1.2193 - val_y2_output_root_mean_squared_error: 1.8325
# Epoch 85/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.5239 - y1_output_loss: 0.8424 - y2_output_loss: 2.7129 - y1_output_root_mean_squared_error: 0.9171 - y2_output_root_mean_squared_error: 1.6379 - val_loss: 10.8626 - val_y1_output_loss: 3.3014 - val_y2_output_loss: 7.3510 - val_y1_output_root_mean_squared_error: 1.8330 - val_y2_output_root_mean_squared_error: 2.7391
# Epoch 86/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.9756 - y1_output_loss: 0.9030 - y2_output_loss: 3.1449 - y1_output_root_mean_squared_error: 0.9494 - y2_output_root_mean_squared_error: 1.7534 - val_loss: 14.3291 - val_y1_output_loss: 1.5483 - val_y2_output_loss: 12.2964 - val_y1_output_root_mean_squared_error: 1.2590 - val_y2_output_root_mean_squared_error: 3.5699
# Epoch 87/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.7206 - y1_output_loss: 0.9353 - y2_output_loss: 2.7518 - y1_output_root_mean_squared_error: 0.9717 - y2_output_root_mean_squared_error: 1.6663 - val_loss: 2.4744 - val_y1_output_loss: 0.6852 - val_y2_output_loss: 1.7042 - val_y1_output_root_mean_squared_error: 0.8431 - val_y2_output_root_mean_squared_error: 1.3280
# Epoch 88/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0144 - y1_output_loss: 0.7487 - y2_output_loss: 2.2501 - y1_output_root_mean_squared_error: 0.8678 - y2_output_root_mean_squared_error: 1.5038 - val_loss: 4.2859 - val_y1_output_loss: 1.3935 - val_y2_output_loss: 2.8292 - val_y1_output_root_mean_squared_error: 1.1744 - val_y2_output_root_mean_squared_error: 1.7049
# Epoch 89/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.7385 - y1_output_loss: 0.8916 - y2_output_loss: 2.8380 - y1_output_root_mean_squared_error: 0.9420 - y2_output_root_mean_squared_error: 1.6886 - val_loss: 3.1893 - val_y1_output_loss: 1.0926 - val_y2_output_loss: 2.0939 - val_y1_output_root_mean_squared_error: 1.0346 - val_y2_output_root_mean_squared_error: 1.4556
# Epoch 90/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8919 - y1_output_loss: 1.2346 - y2_output_loss: 3.6265 - y1_output_root_mean_squared_error: 1.1157 - y2_output_root_mean_squared_error: 1.9098 - val_loss: 3.4246 - val_y1_output_loss: 0.7404 - val_y2_output_loss: 2.5796 - val_y1_output_root_mean_squared_error: 0.8649 - val_y2_output_root_mean_squared_error: 1.6360
# Epoch 91/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3243 - y1_output_loss: 1.1475 - y2_output_loss: 3.1928 - y1_output_root_mean_squared_error: 1.0741 - y2_output_root_mean_squared_error: 1.7806 - val_loss: 7.6253 - val_y1_output_loss: 2.0342 - val_y2_output_loss: 5.3328 - val_y1_output_root_mean_squared_error: 1.4516 - val_y2_output_root_mean_squared_error: 2.3491
# Epoch 92/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3221 - y1_output_loss: 1.1359 - y2_output_loss: 3.1473 - y1_output_root_mean_squared_error: 1.0704 - y2_output_root_mean_squared_error: 1.7822 - val_loss: 4.1903 - val_y1_output_loss: 1.0896 - val_y2_output_loss: 2.9588 - val_y1_output_root_mean_squared_error: 1.0603 - val_y2_output_root_mean_squared_error: 1.7510
# Epoch 93/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6325 - y1_output_loss: 0.6440 - y2_output_loss: 1.9955 - y1_output_root_mean_squared_error: 0.7985 - y2_output_root_mean_squared_error: 1.4124 - val_loss: 6.4939 - val_y1_output_loss: 1.2107 - val_y2_output_loss: 5.0951 - val_y1_output_root_mean_squared_error: 1.1119 - val_y2_output_root_mean_squared_error: 2.2929
# Epoch 94/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.6961 - y1_output_loss: 0.6469 - y2_output_loss: 2.0673 - y1_output_root_mean_squared_error: 0.8023 - y2_output_root_mean_squared_error: 1.4326 - val_loss: 4.4496 - val_y1_output_loss: 0.8017 - val_y2_output_loss: 3.5110 - val_y1_output_root_mean_squared_error: 0.9092 - val_y2_output_root_mean_squared_error: 1.9034
# Epoch 95/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.8312 - y1_output_loss: 0.6866 - y2_output_loss: 2.2135 - y1_output_root_mean_squared_error: 0.8262 - y2_output_root_mean_squared_error: 1.4658 - val_loss: 4.6504 - val_y1_output_loss: 1.1828 - val_y2_output_loss: 3.3243 - val_y1_output_root_mean_squared_error: 1.0977 - val_y2_output_root_mean_squared_error: 1.8562
# Epoch 96/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.5510 - y1_output_loss: 0.8713 - y2_output_loss: 2.6721 - y1_output_root_mean_squared_error: 0.9266 - y2_output_root_mean_squared_error: 1.6408 - val_loss: 2.3358 - val_y1_output_loss: 0.6954 - val_y2_output_loss: 1.5656 - val_y1_output_root_mean_squared_error: 0.8460 - val_y2_output_root_mean_squared_error: 1.2728
# Epoch 97/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.6613 - y1_output_loss: 0.5770 - y2_output_loss: 2.0793 - y1_output_root_mean_squared_error: 0.7616 - y2_output_root_mean_squared_error: 1.4427 - val_loss: 6.0881 - val_y1_output_loss: 1.0328 - val_y2_output_loss: 4.8476 - val_y1_output_root_mean_squared_error: 1.0307 - val_y2_output_root_mean_squared_error: 2.2418
# Epoch 98/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.5236 - y1_output_loss: 0.7727 - y2_output_loss: 2.7485 - y1_output_root_mean_squared_error: 0.8831 - y2_output_root_mean_squared_error: 1.6564 - val_loss: 3.8771 - val_y1_output_loss: 0.8958 - val_y2_output_loss: 2.8983 - val_y1_output_root_mean_squared_error: 0.9495 - val_y2_output_root_mean_squared_error: 1.7250
# Epoch 99/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7902 - y1_output_loss: 0.5977 - y2_output_loss: 2.2518 - y1_output_root_mean_squared_error: 0.7740 - y2_output_root_mean_squared_error: 1.4802 - val_loss: 12.9037 - val_y1_output_loss: 1.7589 - val_y2_output_loss: 10.7458 - val_y1_output_root_mean_squared_error: 1.3493 - val_y2_output_root_mean_squared_error: 3.3291
# Epoch 100/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.4243 - y1_output_loss: 1.0559 - y2_output_loss: 3.3291 - y1_output_root_mean_squared_error: 1.0324 - y2_output_root_mean_squared_error: 1.8326 - val_loss: 4.8207 - val_y1_output_loss: 1.0537 - val_y2_output_loss: 3.6058 - val_y1_output_root_mean_squared_error: 1.0410 - val_y2_output_root_mean_squared_error: 1.9331
# Epoch 101/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.8230 - y1_output_loss: 0.9253 - y2_output_loss: 2.8743 - y1_output_root_mean_squared_error: 0.9611 - y2_output_root_mean_squared_error: 1.7027 - val_loss: 3.0923 - val_y1_output_loss: 1.0481 - val_y2_output_loss: 2.1335 - val_y1_output_root_mean_squared_error: 0.9886 - val_y2_output_root_mean_squared_error: 1.4543
# Epoch 102/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0288 - y1_output_loss: 0.9095 - y2_output_loss: 3.0897 - y1_output_root_mean_squared_error: 0.9559 - y2_output_root_mean_squared_error: 1.7649 - val_loss: 3.1064 - val_y1_output_loss: 0.9311 - val_y2_output_loss: 2.0790 - val_y1_output_root_mean_squared_error: 0.9759 - val_y2_output_root_mean_squared_error: 1.4677
# Epoch 103/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.3735 - y1_output_loss: 0.5514 - y2_output_loss: 1.8192 - y1_output_root_mean_squared_error: 0.7434 - y2_output_root_mean_squared_error: 1.3494 - val_loss: 2.1049 - val_y1_output_loss: 0.6350 - val_y2_output_loss: 1.4539 - val_y1_output_root_mean_squared_error: 0.8011 - val_y2_output_root_mean_squared_error: 1.2096
# Epoch 104/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.7903 - y1_output_loss: 0.6984 - y2_output_loss: 2.0789 - y1_output_root_mean_squared_error: 0.8380 - y2_output_root_mean_squared_error: 1.4450 - val_loss: 2.2419 - val_y1_output_loss: 0.5731 - val_y2_output_loss: 1.5966 - val_y1_output_root_mean_squared_error: 0.7670 - val_y2_output_root_mean_squared_error: 1.2859
# Epoch 105/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.3604 - y1_output_loss: 0.4890 - y2_output_loss: 1.8751 - y1_output_root_mean_squared_error: 0.7011 - y2_output_root_mean_squared_error: 1.3670 - val_loss: 3.0739 - val_y1_output_loss: 0.7465 - val_y2_output_loss: 2.2321 - val_y1_output_root_mean_squared_error: 0.8760 - val_y2_output_root_mean_squared_error: 1.5187
# Epoch 106/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.7706 - y1_output_loss: 0.5991 - y2_output_loss: 2.2198 - y1_output_root_mean_squared_error: 0.7623 - y2_output_root_mean_squared_error: 1.4797 - val_loss: 10.5384 - val_y1_output_loss: 4.3311 - val_y2_output_loss: 7.2185 - val_y1_output_root_mean_squared_error: 1.9871 - val_y2_output_root_mean_squared_error: 2.5670
# Epoch 107/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.7749 - y1_output_loss: 0.9093 - y2_output_loss: 2.8368 - y1_output_root_mean_squared_error: 0.9577 - y2_output_root_mean_squared_error: 1.6905 - val_loss: 2.4502 - val_y1_output_loss: 0.6140 - val_y2_output_loss: 1.7960 - val_y1_output_root_mean_squared_error: 0.7862 - val_y2_output_root_mean_squared_error: 1.3535
# Epoch 108/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.2588 - y1_output_loss: 0.7533 - y2_output_loss: 2.5243 - y1_output_root_mean_squared_error: 0.8696 - y2_output_root_mean_squared_error: 1.5820 - val_loss: 2.1387 - val_y1_output_loss: 0.7035 - val_y2_output_loss: 1.3699 - val_y1_output_root_mean_squared_error: 0.8501 - val_y2_output_root_mean_squared_error: 1.1900
# Epoch 109/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.2563 - y1_output_loss: 0.4708 - y2_output_loss: 1.7650 - y1_output_root_mean_squared_error: 0.6892 - y2_output_root_mean_squared_error: 1.3347 - val_loss: 2.6694 - val_y1_output_loss: 0.8433 - val_y2_output_loss: 1.7670 - val_y1_output_root_mean_squared_error: 0.9245 - val_y2_output_root_mean_squared_error: 1.3471
# Epoch 110/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.5315 - y1_output_loss: 1.3549 - y2_output_loss: 4.1436 - y1_output_root_mean_squared_error: 1.1668 - y2_output_root_mean_squared_error: 2.0421 - val_loss: 2.3336 - val_y1_output_loss: 0.6374 - val_y2_output_loss: 1.6170 - val_y1_output_root_mean_squared_error: 0.8121 - val_y2_output_root_mean_squared_error: 1.2938
# Epoch 111/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.0750 - y1_output_loss: 0.7781 - y2_output_loss: 2.3139 - y1_output_root_mean_squared_error: 0.8727 - y2_output_root_mean_squared_error: 1.5209 - val_loss: 12.1986 - val_y1_output_loss: 3.6565 - val_y2_output_loss: 8.1823 - val_y1_output_root_mean_squared_error: 1.9408 - val_y2_output_root_mean_squared_error: 2.9037
# Epoch 112/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.8167 - y1_output_loss: 0.6262 - y2_output_loss: 2.1934 - y1_output_root_mean_squared_error: 0.7943 - y2_output_root_mean_squared_error: 1.4784 - val_loss: 4.4395 - val_y1_output_loss: 0.6385 - val_y2_output_loss: 3.6694 - val_y1_output_root_mean_squared_error: 0.8102 - val_y2_output_root_mean_squared_error: 1.9450
# Epoch 113/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.8174 - y1_output_loss: 0.5050 - y2_output_loss: 2.2942 - y1_output_root_mean_squared_error: 0.7093 - y2_output_root_mean_squared_error: 1.5213 - val_loss: 2.2450 - val_y1_output_loss: 0.5184 - val_y2_output_loss: 1.6572 - val_y1_output_root_mean_squared_error: 0.7283 - val_y2_output_root_mean_squared_error: 1.3094
# Epoch 114/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.3689 - y1_output_loss: 0.4427 - y2_output_loss: 1.9286 - y1_output_root_mean_squared_error: 0.6656 - y2_output_root_mean_squared_error: 1.3878 - val_loss: 2.9854 - val_y1_output_loss: 0.8088 - val_y2_output_loss: 2.1294 - val_y1_output_root_mean_squared_error: 0.9026 - val_y2_output_root_mean_squared_error: 1.4733
# Epoch 115/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.4144 - y1_output_loss: 0.5015 - y2_output_loss: 1.9627 - y1_output_root_mean_squared_error: 0.7051 - y2_output_root_mean_squared_error: 1.3847 - val_loss: 3.8681 - val_y1_output_loss: 0.8501 - val_y2_output_loss: 2.9968 - val_y1_output_root_mean_squared_error: 0.8858 - val_y2_output_root_mean_squared_error: 1.7560
# Epoch 116/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6542 - y1_output_loss: 0.5169 - y2_output_loss: 2.1268 - y1_output_root_mean_squared_error: 0.7180 - y2_output_root_mean_squared_error: 1.4624 - val_loss: 1.9482 - val_y1_output_loss: 0.6067 - val_y2_output_loss: 1.2837 - val_y1_output_root_mean_squared_error: 0.7888 - val_y2_output_root_mean_squared_error: 1.1515
# Epoch 117/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.4735 - y1_output_loss: 0.5183 - y2_output_loss: 1.9400 - y1_output_root_mean_squared_error: 0.7230 - y2_output_root_mean_squared_error: 1.3967 - val_loss: 2.2840 - val_y1_output_loss: 0.7580 - val_y2_output_loss: 1.4582 - val_y1_output_root_mean_squared_error: 0.8837 - val_y2_output_root_mean_squared_error: 1.2260
# Epoch 118/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.1356 - y1_output_loss: 0.4374 - y2_output_loss: 1.6925 - y1_output_root_mean_squared_error: 0.6600 - y2_output_root_mean_squared_error: 1.3038 - val_loss: 2.1154 - val_y1_output_loss: 0.5617 - val_y2_output_loss: 1.5073 - val_y1_output_root_mean_squared_error: 0.7594 - val_y2_output_root_mean_squared_error: 1.2405
# Epoch 119/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.2092 - y1_output_loss: 0.4379 - y2_output_loss: 1.7696 - y1_output_root_mean_squared_error: 0.6619 - y2_output_root_mean_squared_error: 1.3308 - val_loss: 2.3888 - val_y1_output_loss: 0.4997 - val_y2_output_loss: 1.8281 - val_y1_output_root_mean_squared_error: 0.7127 - val_y2_output_root_mean_squared_error: 1.3715
# Epoch 120/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.1136 - y1_output_loss: 0.4330 - y2_output_loss: 1.6720 - y1_output_root_mean_squared_error: 0.6584 - y2_output_root_mean_squared_error: 1.2962 - val_loss: 2.6942 - val_y1_output_loss: 0.6623 - val_y2_output_loss: 1.9580 - val_y1_output_root_mean_squared_error: 0.8199 - val_y2_output_root_mean_squared_error: 1.4220
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5341 - y1_output_loss: 0.1407 - y2_output_loss: 0.3908 - y1_output_root_mean_squared_error: 0.3762 - y2_output_root_mean_squared_error: 0.6265 - val_loss: 0.8677 - val_y1_output_loss: 0.2438 - val_y2_output_loss: 0.6001 - val_y1_output_root_mean_squared_error: 0.4976 - val_y2_output_root_mean_squared_error: 0.7875
# Epoch 462/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4489 - y1_output_loss: 0.1346 - y2_output_loss: 0.3116 - y1_output_root_mean_squared_error: 0.3683 - y2_output_root_mean_squared_error: 0.5597 - val_loss: 0.7393 - val_y1_output_loss: 0.2704 - val_y2_output_loss: 0.4530 - val_y1_output_root_mean_squared_error: 0.5218 - val_y2_output_root_mean_squared_error: 0.6834
# Epoch 463/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4049 - y1_output_loss: 0.1201 - y2_output_loss: 0.2837 - y1_output_root_mean_squared_error: 0.3467 - y2_output_root_mean_squared_error: 0.5335 - val_loss: 0.8102 - val_y1_output_loss: 0.2781 - val_y2_output_loss: 0.5117 - val_y1_output_root_mean_squared_error: 0.5321 - val_y2_output_root_mean_squared_error: 0.7260
# Epoch 464/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3618 - y1_output_loss: 0.1130 - y2_output_loss: 0.2478 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.4990 - val_loss: 1.3749 - val_y1_output_loss: 0.2562 - val_y2_output_loss: 1.0805 - val_y1_output_root_mean_squared_error: 0.5083 - val_y2_output_root_mean_squared_error: 1.0567
# Epoch 465/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3897 - y1_output_loss: 0.1230 - y2_output_loss: 0.2691 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.5170 - val_loss: 1.1029 - val_y1_output_loss: 0.3254 - val_y2_output_loss: 0.7475 - val_y1_output_root_mean_squared_error: 0.5758 - val_y2_output_root_mean_squared_error: 0.8782
# Epoch 466/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4211 - y1_output_loss: 0.1213 - y2_output_loss: 0.2969 - y1_output_root_mean_squared_error: 0.3494 - y2_output_root_mean_squared_error: 0.5469 - val_loss: 0.7298 - val_y1_output_loss: 0.2496 - val_y2_output_loss: 0.4729 - val_y1_output_root_mean_squared_error: 0.4980 - val_y2_output_root_mean_squared_error: 0.6941
# Epoch 467/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4162 - y1_output_loss: 0.1120 - y2_output_loss: 0.3017 - y1_output_root_mean_squared_error: 0.3357 - y2_output_root_mean_squared_error: 0.5510 - val_loss: 0.7228 - val_y1_output_loss: 0.2226 - val_y2_output_loss: 0.4993 - val_y1_output_root_mean_squared_error: 0.4684 - val_y2_output_root_mean_squared_error: 0.7095
# Epoch 468/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4571 - y1_output_loss: 0.1353 - y2_output_loss: 0.3340 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.5701 - val_loss: 1.9281 - val_y1_output_loss: 0.3214 - val_y2_output_loss: 1.5723 - val_y1_output_root_mean_squared_error: 0.5648 - val_y2_output_root_mean_squared_error: 1.2685
# Epoch 469/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5387 - y1_output_loss: 0.1432 - y2_output_loss: 0.3924 - y1_output_root_mean_squared_error: 0.3791 - y2_output_root_mean_squared_error: 0.6285 - val_loss: 0.8208 - val_y1_output_loss: 0.2472 - val_y2_output_loss: 0.5636 - val_y1_output_root_mean_squared_error: 0.4957 - val_y2_output_root_mean_squared_error: 0.7583
# Epoch 470/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3908 - y1_output_loss: 0.1174 - y2_output_loss: 0.2788 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.5233 - val_loss: 1.0071 - val_y1_output_loss: 0.2373 - val_y2_output_loss: 0.7481 - val_y1_output_root_mean_squared_error: 0.4872 - val_y2_output_root_mean_squared_error: 0.8774
# Epoch 471/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3729 - y1_output_loss: 0.1143 - y2_output_loss: 0.2597 - y1_output_root_mean_squared_error: 0.3374 - y2_output_root_mean_squared_error: 0.5089 - val_loss: 1.0079 - val_y1_output_loss: 0.3152 - val_y2_output_loss: 0.6879 - val_y1_output_root_mean_squared_error: 0.5610 - val_y2_output_root_mean_squared_error: 0.8326
# Epoch 472/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3695 - y1_output_loss: 0.1121 - y2_output_loss: 0.2557 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.5066 - val_loss: 0.6676 - val_y1_output_loss: 0.1948 - val_y2_output_loss: 0.4640 - val_y1_output_root_mean_squared_error: 0.4386 - val_y2_output_root_mean_squared_error: 0.6894
# Epoch 473/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5083 - y1_output_loss: 0.1422 - y2_output_loss: 0.4290 - y1_output_root_mean_squared_error: 0.3528 - y2_output_root_mean_squared_error: 0.6196 - val_loss: 15.5751 - val_y1_output_loss: 4.4402 - val_y2_output_loss: 10.7401 - val_y1_output_root_mean_squared_error: 2.1285 - val_y2_output_root_mean_squared_error: 3.3234
# Epoch 474/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5916 - y1_output_loss: 0.1811 - y2_output_loss: 0.4071 - y1_output_root_mean_squared_error: 0.4263 - y2_output_root_mean_squared_error: 0.6402 - val_loss: 0.8234 - val_y1_output_loss: 0.2553 - val_y2_output_loss: 0.5493 - val_y1_output_root_mean_squared_error: 0.5123 - val_y2_output_root_mean_squared_error: 0.7490
# Epoch 475/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5957 - y1_output_loss: 0.1471 - y2_output_loss: 0.4470 - y1_output_root_mean_squared_error: 0.3853 - y2_output_root_mean_squared_error: 0.6687 - val_loss: 0.7949 - val_y1_output_loss: 0.2535 - val_y2_output_loss: 0.5350 - val_y1_output_root_mean_squared_error: 0.5031 - val_y2_output_root_mean_squared_error: 0.7361
# Epoch 476/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3814 - y1_output_loss: 0.1054 - y2_output_loss: 0.2898 - y1_output_root_mean_squared_error: 0.3250 - y2_output_root_mean_squared_error: 0.5252 - val_loss: 0.7695 - val_y1_output_loss: 0.2036 - val_y2_output_loss: 0.5488 - val_y1_output_root_mean_squared_error: 0.4516 - val_y2_output_root_mean_squared_error: 0.7521
# Epoch 477/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3452 - y1_output_loss: 0.1120 - y2_output_loss: 0.2337 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.4828 - val_loss: 0.7796 - val_y1_output_loss: 0.2426 - val_y2_output_loss: 0.5324 - val_y1_output_root_mean_squared_error: 0.4876 - val_y2_output_root_mean_squared_error: 0.7361
# Epoch 478/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3302 - y1_output_loss: 0.1044 - y2_output_loss: 0.2246 - y1_output_root_mean_squared_error: 0.3239 - y2_output_root_mean_squared_error: 0.4746 - val_loss: 0.9620 - val_y1_output_loss: 0.2860 - val_y2_output_loss: 0.6709 - val_y1_output_root_mean_squared_error: 0.5300 - val_y2_output_root_mean_squared_error: 0.8253
# Epoch 479/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3273 - y1_output_loss: 0.1034 - y2_output_loss: 0.2247 - y1_output_root_mean_squared_error: 0.3229 - y2_output_root_mean_squared_error: 0.4722 - val_loss: 0.8899 - val_y1_output_loss: 0.2254 - val_y2_output_loss: 0.6454 - val_y1_output_root_mean_squared_error: 0.4771 - val_y2_output_root_mean_squared_error: 0.8138
# Epoch 480/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3451 - y1_output_loss: 0.1147 - y2_output_loss: 0.2358 - y1_output_root_mean_squared_error: 0.3375 - y2_output_root_mean_squared_error: 0.4809 - val_loss: 1.5972 - val_y1_output_loss: 0.1988 - val_y2_output_loss: 1.3568 - val_y1_output_root_mean_squared_error: 0.4480 - val_y2_output_root_mean_squared_error: 1.1817
# Epoch 481/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4640 - y1_output_loss: 0.1165 - y2_output_loss: 0.3471 - y1_output_root_mean_squared_error: 0.3415 - y2_output_root_mean_squared_error: 0.5894 - val_loss: 1.8303 - val_y1_output_loss: 0.5358 - val_y2_output_loss: 1.2419 - val_y1_output_root_mean_squared_error: 0.7427 - val_y2_output_root_mean_squared_error: 1.1308
# Epoch 482/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4349 - y1_output_loss: 0.1200 - y2_output_loss: 0.3127 - y1_output_root_mean_squared_error: 0.3465 - y2_output_root_mean_squared_error: 0.5610 - val_loss: 0.7795 - val_y1_output_loss: 0.2618 - val_y2_output_loss: 0.5094 - val_y1_output_root_mean_squared_error: 0.5105 - val_y2_output_root_mean_squared_error: 0.7203
# Epoch 483/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.6140 - y1_output_loss: 0.1558 - y2_output_loss: 0.4672 - y1_output_root_mean_squared_error: 0.3882 - y2_output_root_mean_squared_error: 0.6807 - val_loss: 1.2993 - val_y1_output_loss: 0.4485 - val_y2_output_loss: 0.9210 - val_y1_output_root_mean_squared_error: 0.6331 - val_y2_output_root_mean_squared_error: 0.9479
# Epoch 484/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3850 - y1_output_loss: 0.1146 - y2_output_loss: 0.2710 - y1_output_root_mean_squared_error: 0.3356 - y2_output_root_mean_squared_error: 0.5219 - val_loss: 0.7845 - val_y1_output_loss: 0.2756 - val_y2_output_loss: 0.4926 - val_y1_output_root_mean_squared_error: 0.5292 - val_y2_output_root_mean_squared_error: 0.7102
# Epoch 485/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3433 - y1_output_loss: 0.1011 - y2_output_loss: 0.2415 - y1_output_root_mean_squared_error: 0.3191 - y2_output_root_mean_squared_error: 0.4914 - val_loss: 0.7472 - val_y1_output_loss: 0.2384 - val_y2_output_loss: 0.4951 - val_y1_output_root_mean_squared_error: 0.4894 - val_y2_output_root_mean_squared_error: 0.7125
# Epoch 486/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3178 - y1_output_loss: 0.1058 - y2_output_loss: 0.2102 - y1_output_root_mean_squared_error: 0.3262 - y2_output_root_mean_squared_error: 0.4597 - val_loss: 0.9583 - val_y1_output_loss: 0.3293 - val_y2_output_loss: 0.6015 - val_y1_output_root_mean_squared_error: 0.5813 - val_y2_output_root_mean_squared_error: 0.7876
# Epoch 487/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3285 - y1_output_loss: 0.1066 - y2_output_loss: 0.2393 - y1_output_root_mean_squared_error: 0.3264 - y2_output_root_mean_squared_error: 0.4711 - val_loss: 2.4532 - val_y1_output_loss: 0.3012 - val_y2_output_loss: 2.0924 - val_y1_output_root_mean_squared_error: 0.5320 - val_y2_output_root_mean_squared_error: 1.4732
# Epoch 488/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4695 - y1_output_loss: 0.1220 - y2_output_loss: 0.3451 - y1_output_root_mean_squared_error: 0.3502 - y2_output_root_mean_squared_error: 0.5890 - val_loss: 0.7920 - val_y1_output_loss: 0.2403 - val_y2_output_loss: 0.5505 - val_y1_output_root_mean_squared_error: 0.4845 - val_y2_output_root_mean_squared_error: 0.7465
# Epoch 489/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3619 - y1_output_loss: 0.1146 - y2_output_loss: 0.2465 - y1_output_root_mean_squared_error: 0.3377 - y2_output_root_mean_squared_error: 0.4978 - val_loss: 0.8658 - val_y1_output_loss: 0.2904 - val_y2_output_loss: 0.5590 - val_y1_output_root_mean_squared_error: 0.5425 - val_y2_output_root_mean_squared_error: 0.7560
# Epoch 490/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4610 - y1_output_loss: 0.1233 - y2_output_loss: 0.3364 - y1_output_root_mean_squared_error: 0.3505 - y2_output_root_mean_squared_error: 0.5815 - val_loss: 0.7549 - val_y1_output_loss: 0.2421 - val_y2_output_loss: 0.4960 - val_y1_output_root_mean_squared_error: 0.4932 - val_y2_output_root_mean_squared_error: 0.7153
# Epoch 491/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.6088 - y1_output_loss: 0.1653 - y2_output_loss: 0.4382 - y1_output_root_mean_squared_error: 0.4082 - y2_output_root_mean_squared_error: 0.6650 - val_loss: 0.7466 - val_y1_output_loss: 0.2521 - val_y2_output_loss: 0.4794 - val_y1_output_root_mean_squared_error: 0.5023 - val_y2_output_root_mean_squared_error: 0.7030
# Epoch 492/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3326 - y1_output_loss: 0.1146 - y2_output_loss: 0.2160 - y1_output_root_mean_squared_error: 0.3399 - y2_output_root_mean_squared_error: 0.4659 - val_loss: 0.6952 - val_y1_output_loss: 0.1954 - val_y2_output_loss: 0.4823 - val_y1_output_root_mean_squared_error: 0.4439 - val_y2_output_root_mean_squared_error: 0.7058
# Epoch 493/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.7024 - y1_output_loss: 0.1720 - y2_output_loss: 0.5249 - y1_output_root_mean_squared_error: 0.4166 - y2_output_root_mean_squared_error: 0.7272 - val_loss: 0.6436 - val_y1_output_loss: 0.2103 - val_y2_output_loss: 0.4195 - val_y1_output_root_mean_squared_error: 0.4602 - val_y2_output_root_mean_squared_error: 0.6571
# Epoch 494/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3778 - y1_output_loss: 0.1196 - y2_output_loss: 0.2589 - y1_output_root_mean_squared_error: 0.3444 - y2_output_root_mean_squared_error: 0.5091 - val_loss: 1.0095 - val_y1_output_loss: 0.3773 - val_y2_output_loss: 0.6078 - val_y1_output_root_mean_squared_error: 0.6224 - val_y2_output_root_mean_squared_error: 0.7888
# Epoch 495/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4366 - y1_output_loss: 0.1173 - y2_output_loss: 0.3180 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.5653 - val_loss: 0.7069 - val_y1_output_loss: 0.2449 - val_y2_output_loss: 0.4437 - val_y1_output_root_mean_squared_error: 0.5008 - val_y2_output_root_mean_squared_error: 0.6754
# Epoch 496/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.6954 - y1_output_loss: 0.1616 - y2_output_loss: 0.5327 - y1_output_root_mean_squared_error: 0.4001 - y2_output_root_mean_squared_error: 0.7317 - val_loss: 1.3326 - val_y1_output_loss: 0.2584 - val_y2_output_loss: 1.0332 - val_y1_output_root_mean_squared_error: 0.5148 - val_y2_output_root_mean_squared_error: 1.0332
# Epoch 497/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3448 - y1_output_loss: 0.1201 - y2_output_loss: 0.2247 - y1_output_root_mean_squared_error: 0.3439 - y2_output_root_mean_squared_error: 0.4759 - val_loss: 1.0200 - val_y1_output_loss: 0.3197 - val_y2_output_loss: 0.7058 - val_y1_output_root_mean_squared_error: 0.5443 - val_y2_output_root_mean_squared_error: 0.8507
# Epoch 498/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3496 - y1_output_loss: 0.1077 - y2_output_loss: 0.2414 - y1_output_root_mean_squared_error: 0.3295 - y2_output_root_mean_squared_error: 0.4910 - val_loss: 0.7667 - val_y1_output_loss: 0.2408 - val_y2_output_loss: 0.5133 - val_y1_output_root_mean_squared_error: 0.4927 - val_y2_output_root_mean_squared_error: 0.7238
# Epoch 499/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3516 - y1_output_loss: 0.1126 - y2_output_loss: 0.2376 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4887 - val_loss: 0.9372 - val_y1_output_loss: 0.3505 - val_y2_output_loss: 0.5717 - val_y1_output_root_mean_squared_error: 0.5939 - val_y2_output_root_mean_squared_error: 0.7645
# Epoch 500/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4082 - y1_output_loss: 0.1083 - y2_output_loss: 0.2971 - y1_output_root_mean_squared_error: 0.3295 - y2_output_root_mean_squared_error: 0.5474 - val_loss: 0.8008 - val_y1_output_loss: 0.3038 - val_y2_output_loss: 0.4970 - val_y1_output_root_mean_squared_error: 0.5465 - val_y2_output_root_mean_squared_error: 0.7087

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 0.8008 - y1_output_loss: 0.3005 - y2_output_loss: 0.4938 - y1_output_root_mean_squared_error: 0.5465 - y2_output_root_mean_squared_error: 0.7087
# Loss = 0.8008280930581031, Y1_loss = 0.3005073070526123, Y1_mse = 0.5464766025543213, Y2_loss = 0.4938468039035797, Y2_mse = 0.7086547017097473

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
